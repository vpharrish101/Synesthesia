# %% [markdown]
# MAINFILE: -
#
# PENDING:
#
# Require to store emails in database, then pass it as input argument to agent_orch in mainfile
#
#
# Initialize prompts from backend (sysprompts.py)
#     #init_prompt(prompts)
#
# Make prompts editable
#
# Require to store emails in database
#     #ingest_from_json(r"D:\Python311\Pets\Synesthesia\data\email_input.json")
#
# Require to call the rag function to store syntactic and sematic vectors
#     #rag_search.build_idx()
#
# Import optimization (lazy load?)

# %%
DONE: 
Refining prompts need to be done - give it a role of a human being, and then ask it stuff rather than it 
assuming to prevent role mismatches, spam account acctions need to be done like spam means no urgency in other prompts, etc. 
Require to parse and C/AE emails, in main folder.
